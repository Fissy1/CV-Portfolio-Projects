# %% [markdown]
# <a href="https://colab.research.google.com/github/Fissy1/CV-Portfolio-Projects/blob/main/Retail_Shopping_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To import the dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc4a92b0-08b7-4f8b-8d37-92299927f1c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc4a92b0-08b7-4f8b-8d37-92299927f1c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#to view the data in the dataset
covid_data = pd.read_csv('Impact of COVID dataset.csv')
covid_data.head()
# Out:
#                      Timestamp               Name Profession   Age   \
# 0  2021/12/11 5:57:02 am GMT-8  Divyangi Hattarki    Student  18-24
# 1  2021/12/11 5:57:15 am GMT-8             Shreya    Student  18-24
# 2  2021/12/11 6:12:08 am GMT-8              varun    Student  18-24
# 3  2021/12/11 6:18:21 am GMT-8       Charmil jain    Student  18-24
# 4  2021/12/11 6:50:21 am GMT-8      Vidisha singh    Student  18-24
#
#   Do you prefer online over offline shopping during the current Covid-19 crises?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   Do you think that scope for Online shopping has increased in this pandemic period?  \
# 0                                                Yes
# 1                                                Yes
# ...

# %%
#to check basic info of the dataset
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   Timestamp                                                                                                     100 non-null    object
#  1   Name                                                                                                          100 non-null    object
#  2   Profession                                                                                                    100 non-null    object
#  3   Age                                                                                                           100 non-null    object
# ...

# %%
#to check for any missing value
covid_data.isna().sum()
# Out:
# Timestamp                                                                                                       0
# Name                                                                                                            0
# Profession                                                                                                      0
# Age                                                                                                             0
# Do you prefer online over offline shopping during the current Covid-19 crises?                                  0
# Do you think that scope for Online shopping has increased in this pandemic period?                              0
# Do u think that offline stores have incurred loss due to shift in trend to online Shopping in this pandemic?    0
# Do you tend to spend more money if you are shopping online or in store?                                         0
# ...

# %%
#to fill the missing spaces in the dataset
covid_data.fillna('reliable', inplace = True)
covid_data.isna().sum()

# %%
#to check for any duplicate entry
duplicate = covid_data[covid_data.duplicated(keep = False)]
print()

# %%
#to count the unique values in each column
covid_data.nunique()
# Out:
# Timestamp                                                                                                       100
# Name                                                                                                             95
# Profession                                                                                                        4
# Age                                                                                                               4
# Do you prefer online over offline shopping during the current Covid-19 crises?                                    2
# Do you think that scope for Online shopping has increased in this pandemic period?                                2
# Do u think that offline stores have incurred loss due to shift in trend to online Shopping in this pandemic?      2
# Do you tend to spend more money if you are shopping online or in store?                                           2
# ...

# %%
#to drop none needed columns
covid_new_data = covid_data.drop(columns = ['Timestamp', 'Name'],)
covid_new_data.head()
# Out:
#   Profession   Age   \
# 0    Student  18-24
# 1    Student  18-24
# 2    Student  18-24
# 3    Student  18-24
# 4    Student  18-24
#
#   Do you prefer online over offline shopping during the current Covid-19 crises?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   Do you think that scope for Online shopping has increased in this pandemic period?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Do u think that offline stores have incurred loss due to shift in trend to online Shopping in this pandemic?  \
# ...

# %%
#to filter out needed rows
south_atlantic_regions = ['Delaware', 'Florida', 'Georgia', 'Maryland', 'North Carolina', 'South Carolina', 'Virginia', 'West Virginia']
new_shopping_data = shopping_data[shopping_data['Location'].isin(south_atlantic_regions)]
new_shopping_data.head()
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 8             9   26   Male           Coat    Outerwear
# 12           13   61   Male           Coat    Outerwear
# 21           22   31   Male          Pants     Clothing
# 24           25   18   Male         Jacket    Outerwear
# 28           29   54   Male        Handbag  Accessories
#
#     Purchase Amount (USD)        Location  Season  Review Rating  \
# 8                      97   West Virginia  Summer            2.6
# 12                     72        Delaware  Winter            4.5
# 21                     62  North Carolina  Winter            4.1
# 24                     22         Florida    Fall            2.9
# 28                     94  North Carolina    Fall            4.4
#
#     Shipping Type Discount Applied Promo Code Used Payment Method  \
# 8         Express              Yes             Yes          Venmo
# 12        Express              Yes             Yes          Venmo
# ...

# %%
#Univariate analysis
#to count each unique age
age_count = new_shopping_data["Age"].value_counts()
print("Age Counts:\n", age_count)
# Out:
# Age Counts:
#  Age
# 34    20
# 21    20
# 49    19
# 26    16
# 27    16
# 46    16
# 68    16
# 28    16
# 67    15
# 41    15
# 63    15
# 37    15
# 56    15
# 40    15
# 19    14
# 45    14
# 64    14
# 35    13
# 61    13
# 48    13
# 50    13
# 57    13
# 54    13
# 62    13
# 29    12
# 58    12
# 55    12
# 59    12
# 32    12
# 43    12
# 42    11
# 38    11
# 36    11
# 65    11
# 60    11
# 24    11
# 66    11
# 31    10
# 30    10
# 69    10
# 18    10
# 53     9
# 25     9
# 47     9
# 22     8
# 52     7
# 39     7
# 23     7
# 44     6
# 51     5
# 33     5
# 70     5
# 20     3
# Name: count, dtype: int64

# %%
#Univariate analysis
Age_data = new_shopping_data['Age'].value_counts()
plt.figure(figsize=(10,6))
Age_data.plot(kind='bar')
plt.title('Age Distribution')
plt.xlabel('Ages')
plt.ylabel('Frequency')
plt.show()

# %%
#to count each unique gender
gender_count = new_shopping_data["Gender"].value_counts()
print("Gender Counts:\n", gender_count)
# Out:
# Gender Counts:
#  Gender
# Male      437
# Female    194
# Name: count, dtype: int64

# %%
Gender_data = new_shopping_data['Gender'].value_counts()
Gender_data.plot(kind='pie', autopct = '%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
#to count each unique gender
item_purchased_count = new_shopping_data["Item Purchased"].value_counts()
print("Item Purchased Counts:\n", item_purchased_count)
# Out:
# Item Purchased Counts:
#  Item Purchased
# Gloves        33
# Hoodie        31
# Blouse        30
# Skirt         29
# Hat           29
# Scarf         29
# Sandals       28
# Dress         28
# Pants         28
# Socks         27
# Shoes         27
# Sunglasses    26
# Coat          25
# Sneakers      25
# T-shirt       24
# Boots         24
# Shirt         23
# Jewelry       23
# Handbag       23
# Shorts        22
# Sweater       22
# Backpack      20
# Jacket        20
# Belt          18
# Jeans         17
# Name: count, dtype: int64

# %%
item_data = new_shopping_data['Item Purchased'].value_counts()
plt.figure(figsize=(10,6))
item_data.plot(kind='bar')
plt.title('Items Purchased Distribution')
plt.xlabel('Items Purchased')
plt.ylabel('Frequency')
plt.show()

# %%
#to count each unique gender
category_count = new_shopping_data["Category"].value_counts()
print("Category Counts:\n", category_count)

category_data = new_shopping_data['Category'].value_counts()
plt.figure(figsize=(10,6))
category_data.plot(kind='bar')
plt.title('Category Distribution')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()
# Out:
# Category Counts:
#  Category
# Clothing       281
# Accessories    201
# Footwear       104
# Outerwear       45
# Name: count, dtype: int64

# %%
#to count each unique gender
pur_amount_count = new_shopping_data["Purchase Amount (USD)"].value_counts()
print("Purchase Amount Counts:\n", pur_amount_count)

amount_data = new_shopping_data['Purchase Amount (USD)'].value_counts()
plt.figure(figsize=(10,6))
amount_data.plot(kind='bar')
plt.title('Purchase Amount Distribution')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Purchase Amount Counts:
#  Purchase Amount (USD)
# 28    15
# 42    15
# 26    15
# 52    13
# 82    13
#       ..
# 64     4
# 61     3
# 86     3
# 46     3
# 21     3
# Name: count, Length: 81, dtype: int64

# %%
#to count each unique location
location_count = new_shopping_data["Location"].value_counts()
print("Location Counts:\n", location_count)

#to count each unique location
Location_data = new_shopping_data['Location'].value_counts()
plt.figure(figsize=(10,6))
Location_data.plot(kind='bar')
plt.title('Location Distribution')
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.show()
# Out:
# Location Counts:
#  Location
# Delaware          86
# Maryland          86
# West Virginia     81
# Georgia           79
# North Carolina    78
# Virginia          77
# South Carolina    76
# Florida           68
# Name: count, dtype: int64

# %%
#to count each unique shipping type
shipping_count = new_shopping_data["Shipping Type"].value_counts()
print("Shipping Type:\n", shipping_count)

Shipping_data = new_shopping_data['Shipping Type'].value_counts()
plt.figure(figsize=(10,6))
Shipping_data.plot(kind='bar')
plt.title('Shipping Type Distribution')
plt.xlabel('Shipping')
plt.ylabel('Frequency')
plt.show()
# Out:
# Shipping Type:
#  Shipping Type
# Free Shipping     126
# Express           106
# 2-Day Shipping    106
# Standard          101
# Next Day Air       98
# Store Pickup       94
# Name: count, dtype: int64

# %%
season_count = new_shopping_data["Season"].value_counts()
print("Season:\n", season_count)

Season_data = new_shopping_data['Season'].value_counts()
Season_data.plot(kind='pie', autopct = '%1.1f%%')
plt.title('Season Distribution')
plt.show()
# Out:
# Season:
#  Season
# Spring    172
# Fall      160
# Summer    150
# Winter    149
# Name: count, dtype: int64
